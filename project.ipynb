# %%
import data_processing as dp
import pandas as pd


file_path_encounters = 'encounters.csv'
df = dp.load_csv_file(file_path_encounters)
df.head()
# Out:
# Successfully read the file with encoding utf-8 and separator ','
#                                      Id                 START  \
# 0  32c84703-2481-49cd-d571-3899d5820253  2011-01-02T09:26:36Z
# 1  c98059da-320a-c0a6-fced-c8815f3e3f39  2011-01-03T05:44:39Z
# 2  4ad28a3a-2479-782b-f29c-d5b3f41a001e  2011-01-03T14:32:11Z
# 3  c3f4da61-e4b4-21d5-587a-fbc89943bc19  2011-01-03T16:24:45Z
# 4  a9183b4f-2572-72ea-54c2-b3cd038b4be7  2011-01-03T17:36:53Z
#
#                    STOP                               PATIENT  \
# 0  2011-01-02T12:58:36Z  3de74169-7f67-9304-91d4-757e0f3a14d2
# 1  2011-01-03T06:01:42Z  d9ec2e44-32e9-9148-179a-1653348cc4e2
# 2  2011-01-03T14:47:11Z  73babadf-5b2b-fee7-189e-6f41ff213e01
# 3  2011-01-03T16:39:45Z  3b46a0b7-0f34-9b9a-c319-ace4a1f58c0b
# 4  2011-01-03T17:51:53Z  fa006887-d93c-d302-8b89-f3c25f88c0e1
#
#                            ORGANIZATION                                 PAYER  \
# ...

# %%
# Display insights about the DataFrame
dp.display_df_insights(df)
# Out:
# Data Types of Columns:
#  Id                      object
# START                   object
# STOP                    object
# PATIENT                 object
# ORGANIZATION            object
# PAYER                   object
# ENCOUNTERCLASS          object
# CODE                     int64
# DESCRIPTION             object
# BASE_ENCOUNTER_COST    float64
# TOTAL_CLAIM_COST       float64
# PAYER_COVERAGE         float64
# REASONCODE             float64
# REASONDESCRIPTION       object
# dtype: object
#
# Count of Null Values in Each Column:
#  Id                         0
# START                      0
# STOP                       0
# PATIENT                    0
# ORGANIZATION               0
# PAYER                      0
# ENCOUNTERCLASS             0
# CODE                       0
# DESCRIPTION                0
# BASE_ENCOUNTER_COST        0
# TOTAL_CLAIM_COST           0
# PAYER_COVERAGE             0
# REASONCODE             19541
# REASONDESCRIPTION      19541
# dtype: int64
#
# ...

# %%
#columns_to_check =['ENCOUNTERCLASS', 'CODE', 'DESCRIPTION', 'REASONCODE', 'REASONDESCRIPTION', 'TOTAL_CLAIM_COST']

# Display unique values for the specified columns
#dp.display_unique_values(df, columns_to_check)

# %%
table_name = 'encounters'
column = 'TOTAL_CLAIM_COST'
logs = []


print(df.head())
# Out:
#                                      Id                 START  \
# 0  32c84703-2481-49cd-d571-3899d5820253  2011|01|02T09:26:36Z
# 1  c98059da-320a-c0a6-fced-c8815f3e3f39  2011|01|03T05:44:39Z
# 2  4ad28a3a-2479-782b-f29c-d5b3f41a001e  2011|01|03T14:32:11Z
# 3  c3f4da61-e4b4-21d5-587a-fbc89943bc19  2011|01|03T16:24:45Z
# 4  a9183b4f-2572-72ea-54c2-b3cd038b4be7  2011|01|03T17:36:53Z
#
#                    STOP                               PATIENT  \
# 0  2011-01-02T12:58:36Z  3de74169-7f67-9304-91d4-757e0f3a14d2
# 1  2011-01-03T06:01:42Z  d9ec2e44-32e9-9148-179a-1653348cc4e2
# 2  2011-01-03T14:47:11Z  73babadf-5b2b-fee7-189e-6f41ff213e01
# 3  2011-01-03T16:39:45Z  3b46a0b7-0f34-9b9a-c319-ace4a1f58c0b
# 4  2011-01-03T17:51:53Z  fa006887-d93c-d302-8b89-f3c25f88c0e1
#
#                            ORGANIZATION                                 PAYER  \
# 0  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# ...

# %%
log_df = pd.DataFrame(logs, columns=['Table Name', 'Column Name', 'Description'])
# Out:
# Empty DataFrame
# Columns: [Table Name, Column Name, Description]
# Index: []

# %%
columns_to_preprocess = df.columns.tolist()

# Preprocess the specified columns
df = dp.preprocess_columns(df, columns_to_preprocess)
# Out:
#                                      Id                 START  \
# 0  32C84703-2481-49CD-D571-3899D5820253  2011|01|02T09:26:36Z
# 1  C98059DA-320A-C0A6-FCED-C8815F3E3F39  2011|01|03T05:44:39Z
# 2  4AD28A3A-2479-782B-F29C-D5B3F41A001E  2011|01|03T14:32:11Z
# 3  C3F4DA61-E4B4-21D5-587A-FBC89943BC19  2011|01|03T16:24:45Z
# 4  A9183B4F-2572-72EA-54C2-B3CD038B4BE7  2011|01|03T17:36:53Z
#
#                    STOP                               PATIENT  \
# 0  2011-01-02T12:58:36Z  3DE74169-7F67-9304-91D4-757E0F3A14D2
# 1  2011-01-03T06:01:42Z  D9EC2E44-32E9-9148-179A-1653348CC4E2
# 2  2011-01-03T14:47:11Z  73BABADF-5B2B-FEE7-189E-6F41FF213E01
# 3  2011-01-03T16:39:45Z  3B46A0B7-0F34-9B9A-C319-ACE4A1F58C0B
# 4  2011-01-03T17:51:53Z  FA006887-D93C-D302-8B89-F3C25F88C0E1
#
#                            ORGANIZATION                                 PAYER  \
# 0  D78E84EC-30AA-3BBA-A33A-F29A3A454662  B1C428D6-4F07-31E0-90F0-68FFA6FF8C76
# ...

# %%
# Replace specific value with NaN in the specified column
column_to_modify = 'REASONDESCRIPTION'
value_to_replace = 'NAN'

df = dp.replace_value_with_nan(df, column_to_modify, value_to_replace)
df = dp.replace_value_with_nan(df, 'REASONCODE', value_to_replace)
# Out:
#                                      Id                 START  \
# 0  32C84703-2481-49CD-D571-3899D5820253  2011|01|02T09:26:36Z
# 1  C98059DA-320A-C0A6-FCED-C8815F3E3F39  2011|01|03T05:44:39Z
# 2  4AD28A3A-2479-782B-F29C-D5B3F41A001E  2011|01|03T14:32:11Z
# 3  C3F4DA61-E4B4-21D5-587A-FBC89943BC19  2011|01|03T16:24:45Z
# 4  A9183B4F-2572-72EA-54C2-B3CD038B4BE7  2011|01|03T17:36:53Z
#
#                    STOP                               PATIENT  \
# 0  2011-01-02T12:58:36Z  3DE74169-7F67-9304-91D4-757E0F3A14D2
# 1  2011-01-03T06:01:42Z  D9EC2E44-32E9-9148-179A-1653348CC4E2
# 2  2011-01-03T14:47:11Z  73BABADF-5B2B-FEE7-189E-6F41FF213E01
# 3  2011-01-03T16:39:45Z  3B46A0B7-0F34-9B9A-C319-ACE4A1F58C0B
# 4  2011-01-03T17:51:53Z  FA006887-D93C-D302-8B89-F3C25F88C0E1
#
#                            ORGANIZATION                                 PAYER  \
# 0  D78E84EC-30AA-3BBA-A33A-F29A3A454662  B1C428D6-4F07-31E0-90F0-68FFA6FF8C76
# ...

# %%
# Replace NaN values with "VALUE NOT PROVIDED" in the specified columns
columns_to_modify = ['REASONDESCRIPTION']

df = dp.replace_nan_with_value(df, columns_to_modify, table_name, logs)

# Display the modified DataFrame
df.head()
# Out:
#                                      Id                 START  \
# 0  32C84703-2481-49CD-D571-3899D5820253  2011|01|02T09:26:36Z
# 1  C98059DA-320A-C0A6-FCED-C8815F3E3F39  2011|01|03T05:44:39Z
# 2  4AD28A3A-2479-782B-F29C-D5B3F41A001E  2011|01|03T14:32:11Z
# 3  C3F4DA61-E4B4-21D5-587A-FBC89943BC19  2011|01|03T16:24:45Z
# 4  A9183B4F-2572-72EA-54C2-B3CD038B4BE7  2011|01|03T17:36:53Z
#
#                    STOP                               PATIENT  \
# 0  2011-01-02T12:58:36Z  3DE74169-7F67-9304-91D4-757E0F3A14D2
# 1  2011-01-03T06:01:42Z  D9EC2E44-32E9-9148-179A-1653348CC4E2
# 2  2011-01-03T14:47:11Z  73BABADF-5B2B-FEE7-189E-6F41FF213E01
# 3  2011-01-03T16:39:45Z  3B46A0B7-0F34-9B9A-C319-ACE4A1F58C0B
# 4  2011-01-03T17:51:53Z  FA006887-D93C-D302-8B89-F3C25F88C0E1
#
#                            ORGANIZATION                                 PAYER  \
# 0  D78E84EC-30AA-3BBA-A33A-F29A3A454662  B1C428D6-4F07-31E0-90F0-68FFA6FF8C76
# ...

# %%
df = dp.convert_column_to_date(df, 'START', table_name, logs)
df = dp.convert_column_to_float(df, 'BASE_ENCOUNTER_COST', table_name, logs)
df = dp.convert_column_to_float(df, 'TOTAL_CLAIM_COST', table_name, logs)
df = dp.convert_column_to_float(df, 'PAYER_COVERAGE', table_name, logs)
df = dp.convert_column_to_float(df, 'REASONCODE', table_name, logs)
df = dp.convert_columns_to_int(df, ['CODE'], table_name, logs)
# Example usage
df = dp.convert_column_to_date(df, 'STOP', table_name, logs)
df.dtypes
# Out:
# Id                             object
# START                  datetime64[ns]
# STOP                   datetime64[ns]
# PATIENT                        object
# ORGANIZATION                   object
# PAYER                          object
# ENCOUNTERCLASS                 object
# CODE                            int32
# DESCRIPTION                    object
# BASE_ENCOUNTER_COST           float64
# TOTAL_CLAIM_COST              float64
# PAYER_COVERAGE                float64
# REASONCODE                    float64
# REASONDESCRIPTION              object
# dtype: object

# %%
# Replace NaN values with 0 in numerical columns
df = dp.replace_nan_in_numeric_columns(df, table_name, logs)

# Display the modified DataFrame
df.head()
# Out:
#                                      Id               START  \
# 0  32C84703-2481-49CD-D571-3899D5820253 2011-01-02 09:26:36
# 1  C98059DA-320A-C0A6-FCED-C8815F3E3F39 2011-01-03 05:44:39
# 2  4AD28A3A-2479-782B-F29C-D5B3F41A001E 2011-01-03 14:32:11
# 3  C3F4DA61-E4B4-21D5-587A-FBC89943BC19 2011-01-03 16:24:45
# 4  A9183B4F-2572-72EA-54C2-B3CD038B4BE7 2011-01-03 17:36:53
#
#                  STOP                               PATIENT  \
# 0 2011-01-02 12:58:36  3DE74169-7F67-9304-91D4-757E0F3A14D2
# 1 2011-01-03 06:01:42  D9EC2E44-32E9-9148-179A-1653348CC4E2
# 2 2011-01-03 14:47:11  73BABADF-5B2B-FEE7-189E-6F41FF213E01
# 3 2011-01-03 16:39:45  3B46A0B7-0F34-9B9A-C319-ACE4A1F58C0B
# 4 2011-01-03 17:51:53  FA006887-D93C-D302-8B89-F3C25F88C0E1
#
#                            ORGANIZATION                                 PAYER  \
# 0  D78E84EC-30AA-3BBA-A33A-F29A3A454662  B1C428D6-4F07-31E0-90F0-68FFA6FF8C76
# 1  D78E84EC-30AA-3BBA-A33A-F29A3A454662  B1C428D6-4F07-31E0-90F0-68FFA6FF8C76
# ...

# %%
file_path_encounters_cleaned = 'encounters_cleaned.csv'
#file_path_1 = 'C:/Users/PAVILION/Desktop/Data Analytics Project/log_file.csv'

dp.save_df_to_csv(df, file_path_encounters_cleaned)
#dp.save_df_to_csv(log_df, file_path_1)
# Out:
# DataFrame saved to C:/Users/PAVILION/Desktop/Data Analytics Project/encounters_cleaned.csv successfully.

# %%
file_path_organizations = 'organizations.csv'
df_1 = dp.load_csv_file(file_path_organizations)
# Out:
# Successfully read the file with encoding utf-8 and separator ','

# %%
df_1.head()
# Out:
#                                      Id                            NAME  \
# 0  d78e84ec-30aa-3bba-a33a-f29a3a454662  MASSACHUSETTS GENERAL HOSPITAL
#
#            ADDRESS    CITY STATE   ZIP        LAT        LON
# 0  55 FRUIT STREET  BOSTON    MA  2114  42.362813 -71.069187

# %%
# Display insights about the DataFrame
dp.display_df_insights(df_1)
# Out:
# Data Types of Columns:
#  Id          object
# NAME        object
# ADDRESS     object
# CITY        object
# STATE       object
# ZIP          int64
# LAT        float64
# LON        float64
# dtype: object
#
# Count of Null Values in Each Column:
#  Id         0
# NAME       0
# ADDRESS    0
# CITY       0
# STATE      0
# ZIP        0
# LAT        0
# LON        0
# dtype: int64
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Id       1 non-null      object
#  1   NAME     1 non-null      object
#  2   ADDRESS  1 non-null      object
#  3   CITY     1 non-null      object
#  4   STATE    1 non-null      object
#  5   ZIP      1 non-null      int64
#  6   LAT      1 non-null      float64
#  7   LON      1 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 196.0+ bytes
#
# ...

# %%
columns_to_preprocess_1 = ['Id', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'LAT', 'LON']

# Preprocess the specified columns
df_1 = dp.preprocess_columns(df_1, columns_to_preprocess_1)
df_1
# Out:
#                                      Id                            NAME  \
# 0  D78E84EC-30AA-3BBA-A33A-F29A3A454662  MASSACHUSETTS GENERAL HOSPITAL
#
#            ADDRESS    CITY STATE   ZIP        LAT         LON
# 0  55 FRUIT STREET  BOSTON    MA  2114  42.362813  -71.069187

# %%
file_path_organizations_cleaned = 'organizations_cleaned.csv'

dp.save_df_to_csv(df_1, file_path_organizations_cleaned)
# Out:
# DataFrame saved to C:/Users/PAVILION/Desktop/Data Analytics Project/organizations_cleaned.csv successfully.

# %%
file_path_patients = 'patients.csv'
df_2 = dp.load_csv_file(file_path_patients, ':')
df_2.head()
# Out:
# Successfully read the file with encoding latin1 and separator ':'
#                                      Id   BIRTHDATE   DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977|03-19         NaN   Mrs.
# 1  6e5ae27c-8038-7988-e2c0-25a103f01bfa  1940|02-19         NaN    Mr.
# 2  8123d076-0886-9007-e956-d5864aa121a7  1958|06-04         NaN    Mr.
# 3  770518e4-6133-648e-60c9-071eb2f0e2ce  1928|12-25  2017-09-29    Mr.
# 4  f96addf5-81b9-0aab-7855-d208d3d352c5  1928|12-25  2014-02-23    Mr.
#
#            FIRST           LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY  \
# 0     Nikita578       Erdman779    NaN  Leannon79       M  white  nonhispanic
# 1       Zane918   Hodkiewicz467    NaN        NaN       M  white  nonhispanic
# 2      Quinn173    Marquardt819    NaN        NaN       M  white  nonhispanic
# 3       Abel832      Smitham825    NaN        NaN       M  white     hispanic
# 4      Edwin773      Labadie908    NaN        NaN       M  white     hispanic
#
# ...

# %%
dp.display_df_insights(df_2)
# Out:
# Data Types of Columns:
#  Id             object
# BIRTHDATE      object
# DEATHDATE      object
# PREFIX         object
# FIRST          object
# LAST           object
# SUFFIX         object
# MAIDEN         object
# MARITAL        object
# RACE           object
# ETHNICITY      object
# GENDER         object
# BIRTHPLACE     object
# ADDRESS        object
# CITY           object
# STATE          object
# COUNTY         object
# ZIP           float64
# LAT           float64
# LON           float64
# dtype: object
#
# Count of Null Values in Each Column:
#  Id              0
# BIRTHDATE       0
# DEATHDATE     840
# PREFIX          0
# FIRST           0
# LAST            0
# SUFFIX        973
# MAIDEN        600
# MARITAL         1
# RACE            0
# ETHNICITY       0
# GENDER        487
# BIRTHPLACE      0
# ADDRESS         0
# CITY            0
# STATE           0
# COUNTY          0
# ZIP           145
# LAT             0
# LON             0
# dtype: int64
#
# DataFrame Info:
# ...

# %%
# Function to modify the value
def modify_value(value):
    if value.startswith('943|'):
        return '1943|' + value[4:]
    return value

# Apply the function to the specific column
df_2['BIRTHDATE'] = df_2['BIRTHDATE'].apply(modify_value)

# %%
columns_to_check_2 =['BIRTHDATE', 'DEATHDATE', 'PREFIX', 'SUFFIX', 'MAIDEN', 'MARITAL', 'RACE', 'ETHNICITY', 'GENDER', 'CITY', 'STATE', 'COUNTY']
# Display unique values for the specified columns
dp.display_unique_values(df_2, columns_to_check_2)
# Out:
# Unique values in column 'BIRTHDATE':
# ['1977|03-19' '1940|02-19' '1958|06-04' '1928|12-25' '1957|11-08'
#  '1972|06-27' '1954|03-06' '1927|07-10' '1933|05-08' '1948|05-30'
#  '1971|10-27' '1983|04-11' '1939|09-21' '1964|10-15' '1923|03-16'
#  '1979|06-16' '1981|02-17' '1931|12-18' '1932|06-14' '1933|12-09'
#  '1975|02-22' '1931|12-04' '1981|08-05' '1933|09-12' '1937|10-09'
#  '1959|12-02' '1932|03-08' '1942|06-16' '1924|11-19' '1926|07-14'
#  '1966|09-25' '1946|04-02' '1947|08-09' '1923|01-18' '1957|10-14'
#  '1931|04-21' '1925|01-15' '1948|03-28' '1964|04-22' '1980|11-12'
#  '1929|04-01' '1951|03-24' '1925|11-16' '1935|06-25' '1989|02-15'
#  '1924|07-19' '1975|11-14' '1973|02-26' '1965|08-19' '1945|09-10'
#  '1927|11-06' '1950|07-28' '1979|06-24' '1959|02-14' '1936|11-01'
#  '1946|01-16' '1930|05-24' '1981|10-29' '1971|08-26' '1969|03-21'
#  '1966|08-18' '1922|05-31' '1962|12-05' '1969|02-10' '1935|10-01'
#  '1931|03-27' '1931|10-21' '1964|09-16' '1925|06-01' '1935|04-13'
# ...

# %%
table_name_2 = 'patients'
df_2 = dp.convert_date_format(df_2, 'BIRTHDATE', table_name_2, logs)
df_2.head()
# Out:
#                                      Id   BIRTHDATE   DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19         NaN   Mrs.
# 1  6e5ae27c-8038-7988-e2c0-25a103f01bfa  1940-02-19         NaN    Mr.
# 2  8123d076-0886-9007-e956-d5864aa121a7  1958-06-04         NaN    Mr.
# 3  770518e4-6133-648e-60c9-071eb2f0e2ce  1928-12-25  2017-09-29    Mr.
# 4  f96addf5-81b9-0aab-7855-d208d3d352c5  1928-12-25  2014-02-23    Mr.
#
#            FIRST           LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY  \
# 0     Nikita578       Erdman779    NaN  Leannon79       M  white  nonhispanic
# 1       Zane918   Hodkiewicz467    NaN        NaN       M  white  nonhispanic
# 2      Quinn173    Marquardt819    NaN        NaN       M  white  nonhispanic
# 3       Abel832      Smitham825    NaN        NaN       M  white     hispanic
# 4      Edwin773      Labadie908    NaN        NaN       M  white     hispanic
#
# ...

# %%
df_2 = dp.convert_to_date(df_2, 'DEATHDATE', table_name_2, logs)

# %%
# Get all column names from the dataframe
columns_to_preprocess_all = df_2.columns.tolist()

# Preprocess all columns
df_2 = dp.preprocess_columns(df_2, columns_to_preprocess_all)
df_2.head()
# Out:
#                                      Id   BIRTHDATE   DEATHDATE PREFIX  \
# 0  5605B66B-E92D-C16C-1B83-B8BF7040D51F  1977-03-19         NAT   MRS.
# 1  6E5AE27C-8038-7988-E2C0-25A103F01BFA  1940-02-19         NAT    MR.
# 2  8123D076-0886-9007-E956-D5864AA121A7  1958-06-04         NAT    MR.
# 3  770518E4-6133-648E-60C9-071EB2F0E2CE  1928-12-25  2017-09-29    MR.
# 4  F96ADDF5-81B9-0AAB-7855-D208D3D352C5  1928-12-25  2014-02-23    MR.
#
#        FIRST           LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY  \
# 0  NIKITA578      ERDMAN779    NAN  LEANNON79       M  WHITE  NONHISPANIC
# 1    ZANE918  HODKIEWICZ467    NAN        NAN       M  WHITE  NONHISPANIC
# 2   QUINN173   MARQUARDT819    NAN        NAN       M  WHITE  NONHISPANIC
# 3    ABEL832     SMITHAM825    NAN        NAN       M  WHITE     HISPANIC
# 4   EDWIN773     LABADIE908    NAN        NAN       M  WHITE     HISPANIC
#
#   GENDER                    BIRTHPLACE                       ADDRESS    CITY  \
# ...

# %%
df_2 = dp.replace_value_with_nan(df_2, 'DEATHDATE', value_to_replace)
df_2 = dp.replace_value_with_nan(df_2, 'SUFFIX', value_to_replace)
df_2 = dp.replace_value_with_nan(df_2, 'MAIDEN', value_to_replace)
df_2 = dp.replace_value_with_nan(df_2, 'GENDER', value_to_replace)
df_2 = dp.replace_value_with_nan(df_2, 'ZIP', value_to_replace)
df_2.head()
# Out:
#                                      Id   BIRTHDATE   DEATHDATE PREFIX  \
# 0  5605B66B-E92D-C16C-1B83-B8BF7040D51F  1977-03-19         NAT   MRS.
# 1  6E5AE27C-8038-7988-E2C0-25A103F01BFA  1940-02-19         NAT    MR.
# 2  8123D076-0886-9007-E956-D5864AA121A7  1958-06-04         NAT    MR.
# 3  770518E4-6133-648E-60C9-071EB2F0E2CE  1928-12-25  2017-09-29    MR.
# 4  F96ADDF5-81B9-0AAB-7855-D208D3D352C5  1928-12-25  2014-02-23    MR.
#
#        FIRST           LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY  \
# 0  NIKITA578      ERDMAN779    NaN  LEANNON79       M  WHITE  NONHISPANIC
# 1    ZANE918  HODKIEWICZ467    NaN        NaN       M  WHITE  NONHISPANIC
# 2   QUINN173   MARQUARDT819    NaN        NaN       M  WHITE  NONHISPANIC
# 3    ABEL832     SMITHAM825    NaN        NaN       M  WHITE     HISPANIC
# 4   EDWIN773     LABADIE908    NaN        NaN       M  WHITE     HISPANIC
#
#   GENDER                    BIRTHPLACE                       ADDRESS    CITY  \
# ...

# %%
'''DEATHDATE     840
PREFIX          0
FIRST           0
LAST            0
SUFFIX        973
MAIDEN        600
MARITAL         1
RACE            0
ETHNICITY       0
GENDER        487
BIRTHPLACE      0
ADDRESS         0
CITY            0
STATE           0
COUNTY          0
ZIP           145'''
# Replace NaN values with "VALUE NOT PROVIDED" in the specified columns
columns_to_modify_2 = ['SUFFIX', 'MAIDEN', 'GENDER']

df_2= dp.replace_nan_with_value(df_2, columns_to_modify_2, table_name_2, logs, replacement_value="VALUE NOT PROVIDED")
df_2 = dp.replace_nan_in_numeric_columns(df_2, table_name_2, logs)
# Display the modified DataFrame
df_2.head()
# Out:
#                                      Id   BIRTHDATE   DEATHDATE PREFIX  \
# 0  5605B66B-E92D-C16C-1B83-B8BF7040D51F  1977-03-19         NAT   MRS.
# 1  6E5AE27C-8038-7988-E2C0-25A103F01BFA  1940-02-19         NAT    MR.
# 2  8123D076-0886-9007-E956-D5864AA121A7  1958-06-04         NAT    MR.
# 3  770518E4-6133-648E-60C9-071EB2F0E2CE  1928-12-25  2017-09-29    MR.
# 4  F96ADDF5-81B9-0AAB-7855-D208D3D352C5  1928-12-25  2014-02-23    MR.
#
#        FIRST           LAST              SUFFIX              MAIDEN MARITAL  \
# 0  NIKITA578      ERDMAN779  VALUE NOT PROVIDED           LEANNON79       M
# 1    ZANE918  HODKIEWICZ467  VALUE NOT PROVIDED  VALUE NOT PROVIDED       M
# 2   QUINN173   MARQUARDT819  VALUE NOT PROVIDED  VALUE NOT PROVIDED       M
# 3    ABEL832     SMITHAM825  VALUE NOT PROVIDED  VALUE NOT PROVIDED       M
# 4   EDWIN773     LABADIE908  VALUE NOT PROVIDED  VALUE NOT PROVIDED       M
#
#     RACE    ETHNICITY              GENDER                    BIRTHPLACE  \
# ...

# %%
df_2 = dp.convert_column_to_float(df_2, 'LAT', table_name_2, logs)
df_2 = dp.convert_column_to_float(df_2, 'LON', table_name_2, logs)
df_2 = dp.convert_column_to_float(df_2, 'ZIP', table_name_2, logs)
df_2 = dp.convert_to_date(df_2, 'BIRTHDATE', table_name_2, logs)
df_2 = dp.convert_to_date(df_2, 'DEATHDATE', table_name_2, logs)

# %%
columns_to_check_22 =['DEATHDATE', 'SUFFIX', 'MAIDEN', 'GENDER', 'ZIP']
# Display unique values for the specified columns
dp.display_unique_values(df_2, columns_to_check_22)
# Out:
# Unique values in column 'DEATHDATE':
# <DatetimeArray>
# [                'NaT', '2017-09-29 00:00:00', '2014-02-23 00:00:00',
#  '2021-03-26 00:00:00', '2014-04-21 00:00:00', '2016-11-06 00:00:00',
#  '2012-11-22 00:00:00', '2018-05-27 00:00:00', '2014-01-13 00:00:00',
#  '2021-01-13 00:00:00',
#  ...
#  '2015-02-19 00:00:00', '2018-04-08 00:00:00', '2019-08-28 00:00:00',
#  '2019-10-28 00:00:00', '2016-12-30 00:00:00', '2020-11-15 00:00:00',
#  '2018-05-16 00:00:00', '2017-01-19 00:00:00', '2014-11-16 00:00:00',
#  '2018-03-29 00:00:00']
# Length: 149, dtype: datetime64[ns]
#
#
# Unique values in column 'SUFFIX':
# ['VALUE NOT PROVIDED' 'PHD' 'JD' 'MD']
#
#
# Unique values in column 'MAIDEN':
# ['LEANNON79' 'VALUE NOT PROVIDED' 'WIEGAND701' 'PREDOVIC534' 'WALKER122'
#  'UPTON904' 'HERMANN103' 'CRONA259' 'LEGROS616' 'GREENHOLT190' 'METZ686'
#  'PFEFFER420' 'BRIONES478' 'COLE117' 'KASSULKE119' 'ARMSTRONG51'
#  'MACEJKOVIC424' 'BECHTELAR572' 'SIMONIS280' 'CARTER549' 'QUITZON246'
# ...

# %%
file_path_patients_cleaned = 'patients_cleaned.csv'

dp.save_df_to_csv(df_2, file_path_patients_cleaned)
# Out:
# DataFrame saved to C:/Users/PAVILION/Desktop/Data Analytics Project/patients_cleaned.csv successfully.

# %%
file_path_payers = 'payers.csv'
df_3 = dp.load_csv_file(file_path_payers)
df_3
# Out:
# Successfully read the file with encoding utf-8 and separator ','
#                                      Id                    NAME  \
# 0  b3221cfc-24fb-339e-823d-bc4136cbc4ed           Dual Eligible
# 1  7caa7254-5050-3b5e-9eae-bd5ea30e809c                Medicare
# 2  7c4411ce-02f1-39b5-b9ec-dfbea9ad3c1a                Medicaid
# 3  d47b3510-2895-3b70-9897-342d681c769d                  Humana
# 4  6e2f1a2d-27bd-3701-8d08-dae202c58632  Blue Cross Blue Shield
# 5  5059a55e-5d6e-34d1-b6cb-d83d16e57bcf        UnitedHealthcare
# 6  4d71f845-a6a9-3c39-b242-14d25ef86a8d                   Aetna
# 7  047f6ec3-6215-35eb-9608-f9dda363a44c            Cigna Health
# 8  42c4fca7-f8a9-3cd1-982a-dd9751bf3e2a                  Anthem
# 9  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76            NO_INSURANCE
#
#                 ADDRESS          CITY STATE_HEADQUARTERED      ZIP  \
# 0    7500 Security Blvd     Baltimore                  MD  21244.0
# ...

# %%
df_3.dtypes
# Out:
# Id                      object
# NAME                    object
# ADDRESS                 object
# CITY                    object
# STATE_HEADQUARTERED     object
# ZIP                    float64
# PHONE                   object
# dtype: object

# %%
columns_to_modify_3 = ['ADDRESS', 'CITY', 'STATE_HEADQUARTERED', 'PHONE']
table_name_3 = 'payers'
df_3 = dp.replace_nan_with_value(df_3, columns_to_modify_3, table_name_3, logs, replacement_value="VALUE NOT PROVIDED")
df_3 = dp.replace_nan_in_numeric_columns(df_3, table_name_3, logs)

# %%
df_3
# Out:
#                                      Id                    NAME  \
# 0  b3221cfc-24fb-339e-823d-bc4136cbc4ed           Dual Eligible
# 1  7caa7254-5050-3b5e-9eae-bd5ea30e809c                Medicare
# 2  7c4411ce-02f1-39b5-b9ec-dfbea9ad3c1a                Medicaid
# 3  d47b3510-2895-3b70-9897-342d681c769d                  Humana
# 4  6e2f1a2d-27bd-3701-8d08-dae202c58632  Blue Cross Blue Shield
# 5  5059a55e-5d6e-34d1-b6cb-d83d16e57bcf        UnitedHealthcare
# 6  4d71f845-a6a9-3c39-b242-14d25ef86a8d                   Aetna
# 7  047f6ec3-6215-35eb-9608-f9dda363a44c            Cigna Health
# 8  42c4fca7-f8a9-3cd1-982a-dd9751bf3e2a                  Anthem
# 9  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76            NO_INSURANCE
#
#                 ADDRESS                CITY STATE_HEADQUARTERED      ZIP  \
# 0    7500 Security Blvd           Baltimore                  MD  21244.0
# 1    7500 Security Blvd           Baltimore                  MD  21244.0
# ...

# %%
# Get all column names from the dataframe
columns_to_preprocess_all_3 = df_3.columns.tolist()

# Preprocess all columns
df_3 = dp.preprocess_columns(df_3, columns_to_preprocess_all_3)
df_3
# Out:
#                                      Id                    NAME  \
# 0  B3221CFC-24FB-339E-823D-BC4136CBC4ED           DUAL ELIGIBLE
# 1  7CAA7254-5050-3B5E-9EAE-BD5EA30E809C                MEDICARE
# 2  7C4411CE-02F1-39B5-B9EC-DFBEA9AD3C1A                MEDICAID
# 3  D47B3510-2895-3B70-9897-342D681C769D                  HUMANA
# 4  6E2F1A2D-27BD-3701-8D08-DAE202C58632  BLUE CROSS BLUE SHIELD
# 5  5059A55E-5D6E-34D1-B6CB-D83D16E57BCF        UNITEDHEALTHCARE
# 6  4D71F845-A6A9-3C39-B242-14D25EF86A8D                   AETNA
# 7  047F6EC3-6215-35EB-9608-F9DDA363A44C            CIGNA HEALTH
# 8  42C4FCA7-F8A9-3CD1-982A-DD9751BF3E2A                  ANTHEM
# 9  B1C428D6-4F07-31E0-90F0-68FFA6FF8C76            NO_INSURANCE
#
#                 ADDRESS                CITY STATE_HEADQUARTERED      ZIP  \
# 0    7500 SECURITY BLVD           BALTIMORE                  MD  21244.0
# 1    7500 SECURITY BLVD           BALTIMORE                  MD  21244.0
# ...

# %%
file_path_payers_cleaned = 'C:/Users/PAVILION/Desktop/Data Analytics Project/payers_cleaned.csv'

dp.save_df_to_csv(df_3, file_path_payers_cleaned)
# Out:
# DataFrame saved to C:/Users/PAVILION/Desktop/Data Analytics Project/payers_cleaned.csv successfully.

# %%
file_path_procedures = 'procedures.csv'
df_4 = dp.load_csv_file(file_path_procedures)
# Out:
# Successfully read the file with encoding utf-8 and separator ','

# %%
dp.display_df_insights(df_4)
# Out:
# Data Types of Columns:
#  START                 object
# STOP                  object
# PATIENT               object
# ENCOUNTER             object
# CODE                   int64
# DESCRIPTION           object
# BASE_COST              int64
# REASONCODE           float64
# REASONDESCRIPTION     object
# dtype: object
#
# Count of Null Values in Each Column:
#  START                    0
# STOP                     0
# PATIENT                  0
# ENCOUNTER                0
# CODE                     0
# DESCRIPTION              0
# BASE_COST                0
# REASONCODE           36945
# REASONDESCRIPTION    36945
# dtype: int64
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47701 entries, 0 to 47700
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   START              47701 non-null  object
#  1   STOP               47701 non-null  object
# ...

# %%
# Get all column names from the dataframe
columns_to_preprocess_all_4 = df_4.columns.tolist()

# Preprocess all columns
df_4 = dp.preprocess_columns(df_4, columns_to_preprocess_all_4)
df_4.head()
# Out:
#                   START                  STOP  \
# 0  2011-01-02T09:26:36Z  2011-01-02T12:58:36Z
# 1  2011-01-03T05:44:39Z  2011-01-03T06:01:42Z
# 2  2011-01-04T14:49:55Z  2011-01-04T15:04:55Z
# 3  2011-01-05T04:02:09Z  2011-01-05T04:17:09Z
# 4  2011-01-05T12:58:36Z  2011-01-05T16:42:36Z
#
#                                 PATIENT                             ENCOUNTER  \
# 0  3DE74169-7F67-9304-91D4-757E0F3A14D2  32C84703-2481-49CD-D571-3899D5820253
# 1  D9EC2E44-32E9-9148-179A-1653348CC4E2  C98059DA-320A-C0A6-FCED-C8815F3E3F39
# 2  D856D6E6-4C98-E7A2-129B-44076C63D008  2CFD4DDD-AD13-FE1E-528B-15051CEA2EC3
# 3  BC9D59C3-0A30-6E3B-F47D-022E4F03C8DE  17966936-0878-F4DB-128B-A43AE10D0878
# 4  3DE74169-7F67-9304-91D4-757E0F3A14D2  9DE5F0B0-4BA4-CE6F-45FB-B55C202F31A5
#
#         CODE                                        DESCRIPTION BASE_COST  \
# 0  265764009                         RENAL DIALYSIS (PROCEDURE)       903
# ...

# %%
df_4 = dp.replace_value_with_nan(df_4, 'REASONCODE', value_to_replace)
df_4 = dp.replace_value_with_nan(df_4, 'REASONDESCRIPTION', value_to_replace)
df_4.head()
# Out:
#                   START                  STOP  \
# 0  2011-01-02T09:26:36Z  2011-01-02T12:58:36Z
# 1  2011-01-03T05:44:39Z  2011-01-03T06:01:42Z
# 2  2011-01-04T14:49:55Z  2011-01-04T15:04:55Z
# 3  2011-01-05T04:02:09Z  2011-01-05T04:17:09Z
# 4  2011-01-05T12:58:36Z  2011-01-05T16:42:36Z
#
#                                 PATIENT                             ENCOUNTER  \
# 0  3DE74169-7F67-9304-91D4-757E0F3A14D2  32C84703-2481-49CD-D571-3899D5820253
# 1  D9EC2E44-32E9-9148-179A-1653348CC4E2  C98059DA-320A-C0A6-FCED-C8815F3E3F39
# 2  D856D6E6-4C98-E7A2-129B-44076C63D008  2CFD4DDD-AD13-FE1E-528B-15051CEA2EC3
# 3  BC9D59C3-0A30-6E3B-F47D-022E4F03C8DE  17966936-0878-F4DB-128B-A43AE10D0878
# 4  3DE74169-7F67-9304-91D4-757E0F3A14D2  9DE5F0B0-4BA4-CE6F-45FB-B55C202F31A5
#
#         CODE                                        DESCRIPTION BASE_COST  \
# 0  265764009                         RENAL DIALYSIS (PROCEDURE)       903
# ...

# %%
table_name_4 = 'procedures'
df_4 = dp.convert_column_to_float(df_4, 'REASONCODE', table_name_4, logs)
df_4 = dp.convert_columns_to_int(df_4, ['CODE', 'BASE_COST'], table_name_4, logs)
df_4 = dp.convert_column_to_date(df_4, 'START', table_name_4, logs)
df_4 = dp.convert_column_to_date(df_4, 'STOP', table_name_4, logs)
df_4.head()
# Out:
#                 START                STOP  \
# 0 2011-01-02 09:26:36 2011-01-02 12:58:36
# 1 2011-01-03 05:44:39 2011-01-03 06:01:42
# 2 2011-01-04 14:49:55 2011-01-04 15:04:55
# 3 2011-01-05 04:02:09 2011-01-05 04:17:09
# 4 2011-01-05 12:58:36 2011-01-05 16:42:36
#
#                                 PATIENT                             ENCOUNTER  \
# 0  3DE74169-7F67-9304-91D4-757E0F3A14D2  32C84703-2481-49CD-D571-3899D5820253
# 1  D9EC2E44-32E9-9148-179A-1653348CC4E2  C98059DA-320A-C0A6-FCED-C8815F3E3F39
# 2  D856D6E6-4C98-E7A2-129B-44076C63D008  2CFD4DDD-AD13-FE1E-528B-15051CEA2EC3
# 3  BC9D59C3-0A30-6E3B-F47D-022E4F03C8DE  17966936-0878-F4DB-128B-A43AE10D0878
# 4  3DE74169-7F67-9304-91D4-757E0F3A14D2  9DE5F0B0-4BA4-CE6F-45FB-B55C202F31A5
#
#         CODE                                        DESCRIPTION  BASE_COST  \
# 0  265764009                         RENAL DIALYSIS (PROCEDURE)        903
# 1   76601001                            INTRAMUSCULAR INJECTION       2477
# ...

# %%
df_4 = dp.replace_nan_with_value(df_4, ['REASONDESCRIPTION'], table_name_4, logs, replacement_value="VALUE NOT PROVIDED")
df_4 = dp.replace_nan_in_numeric_columns(df_4, table_name_4, logs)

# %%
df_4.head()
# Out:
#                 START                STOP  \
# 0 2011-01-02 09:26:36 2011-01-02 12:58:36
# 1 2011-01-03 05:44:39 2011-01-03 06:01:42
# 2 2011-01-04 14:49:55 2011-01-04 15:04:55
# 3 2011-01-05 04:02:09 2011-01-05 04:17:09
# 4 2011-01-05 12:58:36 2011-01-05 16:42:36
#
#                                 PATIENT                             ENCOUNTER  \
# 0  3DE74169-7F67-9304-91D4-757E0F3A14D2  32C84703-2481-49CD-D571-3899D5820253
# 1  D9EC2E44-32E9-9148-179A-1653348CC4E2  C98059DA-320A-C0A6-FCED-C8815F3E3F39
# 2  D856D6E6-4C98-E7A2-129B-44076C63D008  2CFD4DDD-AD13-FE1E-528B-15051CEA2EC3
# 3  BC9D59C3-0A30-6E3B-F47D-022E4F03C8DE  17966936-0878-F4DB-128B-A43AE10D0878
# 4  3DE74169-7F67-9304-91D4-757E0F3A14D2  9DE5F0B0-4BA4-CE6F-45FB-B55C202F31A5
#
#         CODE                                        DESCRIPTION  BASE_COST  \
# 0  265764009                         RENAL DIALYSIS (PROCEDURE)        903
# 1   76601001                            INTRAMUSCULAR INJECTION       2477
# ...

# %%
df = dp.convert_column_to_float(df, column, table_name, logs)
log_df = pd.DataFrame(logs, columns=['Table Name', 'Column Name', 'Description'])
log_df = log_df.drop_duplicates()
log_df
# Out:
#       Table Name          Column Name  \
# 0     encounters    REASONDESCRIPTION
# 1     encounters                START
# 2     encounters                 STOP
# 3       patients            BIRTHDATE
# 997     patients            DEATHDATE
# 998     patients               SUFFIX
# 999     patients               MAIDEN
# 1000    patients               GENDER
# 1001    patients                  LAT
# 1002    patients                  LON
# 1003    patients                  ZIP
# 1004    patients            BIRTHDATE
# 1006      payers              ADDRESS
# 1007      payers                 CITY
# 1008      payers  STATE_HEADQUARTERED
# 1009      payers                PHONE
# 1010      payers                  ZIP
# 1011  procedures           REASONCODE
# 1012  procedures                 CODE
# 1013  procedures            BASE_COST
# 1014  procedures                START
# 1015  procedures                 STOP
# 1016  procedures    REASONDESCRIPTION
# ...

# %%
file_path_procedures_cleaned = 'procedures_cleaned.csv'
dp.save_df_to_csv(df_4, file_path_procedures_cleaned)

file_path_log = '/log.csv'
dp.save_df_to_csv(log_df, file_path_log)
# Out:
# DataFrame saved to C:/Users/PAVILION/Desktop/Data Analytics Project/procedures_cleaned.csv successfully.
# DataFrame saved to C:/Users/PAVILION/Desktop/Data Analytics Project/log.csv successfully.
